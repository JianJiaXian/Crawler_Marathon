# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
#r.text
import requests
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"26890963409","type":"PushEvent","actor":{"id":58048357,"login":"stellurion","display_login":"stellurion","gravatar_id":"","url":"https://api.github.com/users/stellurion","avatar_url":"https://avatars.githubusercontent.com/u/58048357?"},"repo":{"id":598032742,"name":"stellurion/stellurion","url":"https://api.github.com/repos/stellurion/stellurion"},"payload":{"push_id":12520990553,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1","before":"5650e9b9840b74b74458713d3e5ab45827eab4f6","commits":[{"sha":"5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1","author":{"email":"58048357+stellurion@users.noreply.github.com","name":"stellurion"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/stellurion/stellurion/commits/5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1"}]},"public":true,"created_at":"2023-02-06T08:54:04Z"},{"id":"26890963397","type":"PushEvent","actor":{"id":752371,"login":"iOvergaard","display_login":"iOvergaard","gravatar_id":"","url":"https://api.github.com/users/iOvergaard","avatar_url":"https://avatars.githubusercontent.com/u/752371?"},"repo":{"id":315865767,"name":"umbraco/Umbraco.UI","url":"https://api.github.com/repos/umbraco/Umbraco.UI"},"payload":{"push_id":12520990572,"size":3,"distinct_size":0,"ref":"refs/heads/release/1.2.0","head":"1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d","before":"2ced2909bdbea6539b1fe9be996800bba1cd6880","commits":[{"sha":"e843194646f3f176c049a5fe45a0c2ce1c8541d1","author":{"email":"752371+iOvergaard@users.noreply.github.com","name":"Jacob Overgaard"},"message":"update workflows","distinct":false,"url":"https://api.github.com/repos/umbraco/Umbraco.UI/commits/e843194646f3f176c049a5fe45a0c2ce1c8541d1"},{"sha":"c58f0a3e2e743581cda5a2d4754dc23ae246fc26","author":{"email":"752371+iOvergaard@users.noreply.github.com","name":"Jacob Overgaard"},"message":"chromatic continue on error","distinct":false,"url":"https://api.github.com/repos/umbraco/Umbraco.UI/commits/c58f0a3e2e743581cda5a2d4754dc23ae246fc26"},{"sha":"1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d","author":{"email":"752371+iOvergaard@users.noreply.github.com","name":"Jacob Overgaard"},"message":"only check against contrib branch","distinct":false,"url":"https://api.github.com/repos/umbraco/Umbraco.UI/commits/1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d"}]},"public":true,"created_at":"2023-02-06T08:54:04Z","org":{"id":1419552,"login":"umbraco","gravatar_id":"","url":"https://api.github.com/orgs/umbraco","avatar_url":"https://avatars.githubusercontent.com/u/1419552?"}},{"id":"26890963437","type":"WatchEvent","actor":{"id":124565256,"login":"Michiokaku390","display_login":"Michiokaku390","gravatar_id":"","url":"https://api.github.com/users/Michiokaku390","avatar_url":"https://avatars.githubusercontent.com/u/124565256?"},"repo":{"id":513448433,"name":"Ramenaru/vanillaCSS-portfolio_page","url":"https://api.github.com/repos/Ramenaru/vanillaCSS-portfolio_page"},"payload":{"action":"started"},"public":true,"created_at":"2023-02-06T08:54:04Z"},{"id":"26890963411","type":"PushEvent","actor":{"id":17928155,"login":"MultichartsScannerDataChecker","display_login":"MultichartsScannerDataChecker","gravatar_id":"","url":"https://api.github.com/users/MultichartsScannerDataChecker","avatar_url":"https://avatars.githubusercontent.com/u/17928155?"},"repo":{"id":561412619,"name":"tradingview/scanner-check","url":"https://api.github.com/repos/tradingview/scanner-check"},"payload":{"push_id":12520990566,"size":1,"distinct_size":1,"ref":"refs/heads/dal","head":"6781900791622dfc8f6625eca9b7de05a7351f35","before":"736fed66087364a4722424cb82cd980dfb152648","commits":[{"sha":"6781900791622dfc8f6625eca9b7de05a7351f35","author":{"email":"","name":"robot"},"message":"update black list sweden\\n\\nscanned url http://localhost:9051/sweden/admin/scan\\nsize of black list 92","distinct":true,"url":"https://api.github.com/repos/tradingview/scanner-check/commits/6781900791622dfc8f6625eca9b7de05a7351f35"}]} ...

# %%
#json.loader(r.text)
import json
json.loads(r.text)
# Out:
# [{'id': '26890963409',
#   'type': 'PushEvent',
#   'actor': {'id': 58048357,
#    'login': 'stellurion',
#    'display_login': 'stellurion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stellurion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58048357?'},
#   'repo': {'id': 598032742,
#    'name': 'stellurion/stellurion',
#    'url': 'https://api.github.com/repos/stellurion/stellurion'},
#   'payload': {'push_id': 12520990553,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1',
#    'before': '5650e9b9840b74b74458713d3e5ab45827eab4f6',
#    'commits': [{'sha': '5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1',
#      'author': {'email': '58048357+stellurion@users.noreply.github.com',
#       'name': 'stellurion'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stellurion/stellurion/commits/5ba06c730d1e1e77cf9c2d35d4490253ed7b3be1'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963397',
#   'type': 'PushEvent',
#   'actor': {'id': 752371,
#    'login': 'iOvergaard',
#    'display_login': 'iOvergaard',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iOvergaard',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/752371?'},
#   'repo': {'id': 315865767,
#    'name': 'umbraco/Umbraco.UI',
#    'url': 'https://api.github.com/repos/umbraco/Umbraco.UI'},
#   'payload': {'push_id': 12520990572,
#    'size': 3,
#    'distinct_size': 0,
#    'ref': 'refs/heads/release/1.2.0',
#    'head': '1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d',
#    'before': '2ced2909bdbea6539b1fe9be996800bba1cd6880',
#    'commits': [{'sha': 'e843194646f3f176c049a5fe45a0c2ce1c8541d1',
#      'author': {'email': '752371+iOvergaard@users.noreply.github.com',
#       'name': 'Jacob Overgaard'},
#      'message': 'update workflows',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/umbraco/Umbraco.UI/commits/e843194646f3f176c049a5fe45a0c2ce1c8541d1'},
#     {'sha': 'c58f0a3e2e743581cda5a2d4754dc23ae246fc26',
#      'author': {'email': '752371+iOvergaard@users.noreply.github.com',
#       'name': 'Jacob Overgaard'},
#      'message': 'chromatic continue on error',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/umbraco/Umbraco.UI/commits/c58f0a3e2e743581cda5a2d4754dc23ae246fc26'},
#     {'sha': '1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d',
#      'author': {'email': '752371+iOvergaard@users.noreply.github.com',
#       'name': 'Jacob Overgaard'},
#      'message': 'only check against contrib branch',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/umbraco/Umbraco.UI/commits/1b487ad05e00d1ff7df2eb717cd6ced3203c9d7d'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z',
#   'org': {'id': 1419552,
#    'login': 'umbraco',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/umbraco',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1419552?'}},
#  {'id': '26890963437',
#   'type': 'WatchEvent',
#   'actor': {'id': 124565256,
#    'login': 'Michiokaku390',
#    'display_login': 'Michiokaku390',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Michiokaku390',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124565256?'},
#   'repo': {'id': 513448433,
#    'name': 'Ramenaru/vanillaCSS-portfolio_page',
#    'url': 'https://api.github.com/repos/Ramenaru/vanillaCSS-portfolio_page'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963411',
#   'type': 'PushEvent',
#   'actor': {'id': 17928155,
#    'login': 'MultichartsScannerDataChecker',
#    'display_login': 'MultichartsScannerDataChecker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MultichartsScannerDataChecker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17928155?'},
#   'repo': {'id': 561412619,
#    'name': 'tradingview/scanner-check',
#    'url': 'https://api.github.com/repos/tradingview/scanner-check'},
#   'payload': {'push_id': 12520990566,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dal',
#    'head': '6781900791622dfc8f6625eca9b7de05a7351f35',
#    'before': '736fed66087364a4722424cb82cd980dfb152648',
#    'commits': [{'sha': '6781900791622dfc8f6625eca9b7de05a7351f35',
#      'author': {'email': '', 'name': 'robot'},
#      'message': 'update black list sweden\n\nscanned url http://localhost:9051/sweden/admin/scan\nsize of black list 92',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tradingview/scanner-check/commits/6781900791622dfc8f6625eca9b7de05a7351f35'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z',
#   'org': {'id': 7644688,
#    'login': 'tradingview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tradingview',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7644688?'}},
#  {'id': '26890963360',
#   'type': 'PushEvent',
#   'actor': {'id': 51715343,
#    'login': 'rakesh13145sinha',
#    'display_login': 'rakesh13145sinha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rakesh13145sinha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51715343?'},
#   'repo': {'id': 547093167,
#    'name': 'rakesh13145sinha/dm',
#    'url': 'https://api.github.com/repos/rakesh13145sinha/dm'},
#   'payload': {'push_id': 12520990532,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '077bff75144ec4db28ede6e98a8a6a7f1c40e3b2',
#    'before': '5e4a4514cc7851e57ad2f4913d644807ba43bfd3',
#    'commits': [{'sha': '077bff75144ec4db28ede6e98a8a6a7f1c40e3b2',
#      'author': {'email': 'rakeshsinha8292@gmail.com',
#       'name': 'rakesh13145sinha'},
#      'message': 'UPDATE .ENV FILE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rakesh13145sinha/dm/commits/077bff75144ec4db28ede6e98a8a6a7f1c40e3b2'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963390',
#   'type': 'PushEvent',
#   'actor': {'id': 112165492,
#    'login': 'IvanNikolow12',
#    'display_login': 'IvanNikolow12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IvanNikolow12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112165492?'},
#   'repo': {'id': 579012736,
#    'name': 'IvanNikolow12/JS-Advanced',
#    'url': 'https://api.github.com/repos/IvanNikolow12/JS-Advanced'},
#   'payload': {'push_id': 12520990557,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '61d772569e79013a1ef2d1ffc017930c4c92cff6',
#    'before': 'e612c4a58b8014defdc6260d8509ac40e7361aaf',
#    'commits': [{'sha': '61d772569e79013a1ef2d1ffc017930c4c92cff6',
#      'author': {'email': '112165492+IvanNikolow12@users.noreply.github.com',
#       'name': 'Ivan'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IvanNikolow12/JS-Advanced/commits/61d772569e79013a1ef2d1ffc017930c4c92cff6'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963420',
#   'type': 'ForkEvent',
#   'actor': {'id': 3294100,
#    'login': 'likyh',
#    'display_login': 'likyh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/likyh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3294100?'},
#   'repo': {'id': 596251424,
#    'name': 'jrflga/incubator-devlake',
#    'url': 'https://api.github.com/repos/jrflga/incubator-devlake'},
#   'payload': {'forkee': {'id': 598033202,
#     'node_id': 'R_kgDOI6VDMg',
#     'name': 'incubator-devlake',
#     'full_name': 'likyh/incubator-devlake',
#     'private': False,
#     'owner': {'login': 'likyh',
#      'id': 3294100,
#      'node_id': 'MDQ6VXNlcjMyOTQxMDA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3294100?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/likyh',
#      'html_url': 'https://github.com/likyh',
#      'followers_url': 'https://api.github.com/users/likyh/followers',
#      'following_url': 'https://api.github.com/users/likyh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/likyh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/likyh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/likyh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/likyh/orgs',
#      'repos_url': 'https://api.github.com/users/likyh/repos',
#      'events_url': 'https://api.github.com/users/likyh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/likyh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/likyh/incubator-devlake',
#     'description': 'Apache DevLake is an open-source dev data platform to ingest, analyze, and visualize the fragmented data from DevOps tools, extracting insights for engineering excellence, developer experience, and community growth.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/likyh/incubator-devlake',
#     'forks_url': 'https://api.github.com/repos/likyh/incubator-devlake/forks',
#     'keys_url': 'https://api.github.com/repos/likyh/incubator-devlake/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/likyh/incubator-devlake/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/likyh/incubator-devlake/teams',
#     'hooks_url': 'https://api.github.com/repos/likyh/incubator-devlake/hooks',
#     'issue_events_url': 'https://api.github.com/repos/likyh/incubator-devlake/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/likyh/incubator-devlake/events',
#     'assignees_url': 'https://api.github.com/repos/likyh/incubator-devlake/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/likyh/incubator-devlake/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/likyh/incubator-devlake/tags',
#     'blobs_url': 'https://api.github.com/repos/likyh/incubator-devlake/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/likyh/incubator-devlake/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/likyh/incubator-devlake/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/likyh/incubator-devlake/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/likyh/incubator-devlake/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/likyh/incubator-devlake/languages',
#     'stargazers_url': 'https://api.github.com/repos/likyh/incubator-devlake/stargazers',
#     'contributors_url': 'https://api.github.com/repos/likyh/incubator-devlake/contributors',
#     'subscribers_url': 'https://api.github.com/repos/likyh/incubator-devlake/subscribers',
#     'subscription_url': 'https://api.github.com/repos/likyh/incubator-devlake/subscription',
#     'commits_url': 'https://api.github.com/repos/likyh/incubator-devlake/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/likyh/incubator-devlake/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/likyh/incubator-devlake/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/likyh/incubator-devlake/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/likyh/incubator-devlake/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/likyh/incubator-devlake/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/likyh/incubator-devlake/merges',
#     'archive_url': 'https://api.github.com/repos/likyh/incubator-devlake/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/likyh/incubator-devlake/downloads',
#     'issues_url': 'https://api.github.com/repos/likyh/incubator-devlake/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/likyh/incubator-devlake/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/likyh/incubator-devlake/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/likyh/incubator-devlake/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/likyh/incubator-devlake/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/likyh/incubator-devlake/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/likyh/incubator-devlake/deployments',
#     'created_at': '2023-02-06T08:54:03Z',
#     'updated_at': '2023-02-01T01:57:21Z',
#     'pushed_at': '2023-02-03T16:40:26Z',
#     'git_url': 'git://github.com/likyh/incubator-devlake.git',
#     'ssh_url': 'git@github.com:likyh/incubator-devlake.git',
#     'clone_url': 'https://github.com/likyh/incubator-devlake.git',
#     'svn_url': 'https://github.com/likyh/incubator-devlake',
#     'homepage': 'https://devlake.apache.org/',
#     'size': 22311,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963365',
#   'type': 'PushEvent',
#   'actor': {'id': 115703805,
#    'login': 'pmmapp2022',
#    'display_login': 'pmmapp2022',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pmmapp2022',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115703805?'},
#   'repo': {'id': 558385228,
#    'name': 'pmmapp2022/web_map_points',
#    'url': 'https://api.github.com/repos/pmmapp2022/web_map_points'},
#   'payload': {'push_id': 12520990523,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2ae247a1227030f26991cc435c0509bc62aababa',
#    'before': '108b3d020c3c90fe78db8a2a0a23c58e14a0c91e',
#    'commits': [{'sha': '2ae247a1227030f26991cc435c0509bc62aababa',
#      'author': {'email': 'ubuntu@ip-172-31-38-188', 'name': 'ubuntu'},
#      'message': 'comment from python script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pmmapp2022/web_map_points/commits/2ae247a1227030f26991cc435c0509bc62aababa'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963393',
#   'type': 'PushEvent',
#   'actor': {'id': 30096401,
#    'login': 'dlfpdl',
#    'display_login': 'dlfpdl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dlfpdl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30096401?'},
#   'repo': {'id': 597478547,
#    'name': 'dlfpdl/obsidian',
#    'url': 'https://api.github.com/repos/dlfpdl/obsidian'},
#   'payload': {'push_id': 12520990559,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ff27e6b6955eb15693b38682d97e99a344e38fbb',
#    'before': '8d86535bb36e5602e9c99b34aa2fbe2a38a835b3',
#    'commits': [{'sha': 'ff27e6b6955eb15693b38682d97e99a344e38fbb',
#      'author': {'email': 'raylee@kaist.ac.kr', 'name': 'Dasty-Captain'},
#      'message': 'vault backup: 2023-02-06 17:54:01',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dlfpdl/obsidian/commits/ff27e6b6955eb15693b38682d97e99a344e38fbb'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963333',
#   'type': 'PushEvent',
#   'actor': {'id': 28757366,
#    'login': 'ZhiyuanChen',
#    'display_login': 'ZhiyuanChen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZhiyuanChen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28757366?'},
#   'repo': {'id': 488542508,
#    'name': 'ZhiyuanChen/CHANfiG',
#    'url': 'https://api.github.com/repos/ZhiyuanChen/CHANfiG'},
#   'payload': {'push_id': 12520990515,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e36b9d2916a27f9fae8b604ed74d883dc33a0250',
#    'before': 'f51622cc7b6aff81296660c00347ec3b43f0ed5f',
#    'commits': [{'sha': 'e36b9d2916a27f9fae8b604ed74d883dc33a0250',
#      'author': {'email': 'chenzhiyuan@dp.tech', 'name': 'Zhiyuan Chen'},
#      'message': 'explicit ignore _ipython_canary_ in __missing__\n\nSigned-off-by: Zhiyuan Chen <chenzhiyuan@dp.tech>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZhiyuanChen/CHANfiG/commits/e36b9d2916a27f9fae8b604ed74d883dc33a0250'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963407',
#   'type': 'PushEvent',
#   'actor': {'id': 103050807,
#    'login': 'ravi-sharma26494',
#    'display_login': 'ravi-sharma26494',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ravi-sharma26494',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103050807?'},
#   'repo': {'id': 582730043,
#    'name': 'ravi-sharma26494/inventorymanagement',
#    'url': 'https://api.github.com/repos/ravi-sharma26494/inventorymanagement'},
#   'payload': {'push_id': 12520990547,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '42d4933439cfbba1062d31c5960a8db185d90a2c',
#    'before': 'ea0e5b80ae59fe854bc23983a943eb24d6dcc005',
#    'commits': [{'sha': '42d4933439cfbba1062d31c5960a8db185d90a2c',
#      'author': {'email': 'ravi.sharma26494@gmail.com', 'name': 'Ravi Sharma'},
#      'message': 'Editproduct route&component barebone',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ravi-sharma26494/inventorymanagement/commits/42d4933439cfbba1062d31c5960a8db185d90a2c'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963331',
#   'type': 'PushEvent',
#   'actor': {'id': 108474994,
#    'login': 'appseed-projects3',
#    'display_login': 'appseed-projects3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/appseed-projects3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108474994?'},
#   'repo': {'id': 598032545,
#    'name': 'appseed-projects3/05a7076e-7b25-43b4-978b-9a5b139c20fa',
#    'url': 'https://api.github.com/repos/appseed-projects3/05a7076e-7b25-43b4-978b-9a5b139c20fa'},
#   'payload': {'push_id': 12520990514,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6b591938852264dd451c5ee475218812abfb56e9',
#    'before': '6adbdac8369642dab0867ca63cb056c8d13acd8c',
#    'commits': [{'sha': '6b591938852264dd451c5ee475218812abfb56e9',
#      'author': {'email': '108474994+appseed-projects3@users.noreply.github.com',
#       'name': 'AppSeed Generated Projects'},
#      'message': 'initial commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/appseed-projects3/05a7076e-7b25-43b4-978b-9a5b139c20fa/commits/6b591938852264dd451c5ee475218812abfb56e9'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963361',
#   'type': 'CreateEvent',
#   'actor': {'id': 2233003,
#    'login': 'damienlagae',
#    'display_login': 'damienlagae',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/damienlagae',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2233003?'},
#   'repo': {'id': 571535387,
#    'name': 'Enabel/coding-standard-bundle',
#    'url': 'https://api.github.com/repos/Enabel/coding-standard-bundle'},
#   'payload': {'ref': '1.0.6',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'Enabel bundle that provide coding standard and dev helpers',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z',
#   'org': {'id': 66338676,
#    'login': 'Enabel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Enabel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66338676?'}},
#  {'id': '26890963369',
#   'type': 'DeleteEvent',
#   'actor': {'id': 108680445,
#    'login': 'LuongoAndrea',
#    'display_login': 'LuongoAndrea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuongoAndrea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108680445?'},
#   'repo': {'id': 596014618,
#    'name': 'AndreaGallini/progetto_finale_boolean',
#    'url': 'https://api.github.com/repos/AndreaGallini/progetto_finale_boolean'},
#   'payload': {'ref': 'andrea-luongo-request-mediabook-e-service',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963310',
#   'type': 'PushEvent',
#   'actor': {'id': 84667750,
#    'login': 'PedroFrancoDev',
#    'display_login': 'PedroFrancoDev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PedroFrancoDev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84667750?'},
#   'repo': {'id': 597378489,
#    'name': 'PedroFrancoDev/web-developer-challenge',
#    'url': 'https://api.github.com/repos/PedroFrancoDev/web-developer-challenge'},
#   'payload': {'push_id': 12520990498,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2458bbd50c7a93a24c58e16a20b7a4da9c4df489',
#    'before': 'e087fa9378da43cbcf293a2b8de89a34539782aa',
#    'commits': [{'sha': '2458bbd50c7a93a24c58e16a20b7a4da9c4df489',
#      'author': {'email': 'pedrofrancodev@gmail.com', 'name': 'Pedro Franco'},
#      'message': 'feat: Adding button delete image in form component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PedroFrancoDev/web-developer-challenge/commits/2458bbd50c7a93a24c58e16a20b7a4da9c4df489'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963284',
#   'type': 'PushEvent',
#   'actor': {'id': 123717049,
#    'login': 'SoonDoekKwon',
#    'display_login': 'SoonDoekKwon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SoonDoekKwon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123717049?'},
#   'repo': {'id': 594668108,
#    'name': 'SoonDoekKwon/Task_JAVA',
#    'url': 'https://api.github.com/repos/SoonDoekKwon/Task_JAVA'},
#   'payload': {'push_id': 12520990510,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e5ee456eb604091e8b309eae6838cd2911e217ea',
#    'before': '8c3f2620224bd162b81a3fa2e622b6956c575890',
#    'commits': [{'sha': 'e5ee456eb604091e8b309eae6838cd2911e217ea',
#      'author': {'email': 'admin@YD05-19', 'name': 'admin'},
#      'message': 'homework',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SoonDoekKwon/Task_JAVA/commits/e5ee456eb604091e8b309eae6838cd2911e217ea'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963314',
#   'type': 'PushEvent',
#   'actor': {'id': 124559883,
#    'login': 'RazorGazer',
#    'display_login': 'RazorGazer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RazorGazer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124559883?'},
#   'repo': {'id': 598008905,
#    'name': 'RazorGazer/Wireless-and-mobile-computing',
#    'url': 'https://api.github.com/repos/RazorGazer/Wireless-and-mobile-computing'},
#   'payload': {'push_id': 12520990550,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b7f16356ea1091384047611da29258b9bcf2ff73',
#    'before': 'a8cdd700708bcd5385f4a1bab0f72c18d8b5371b',
#    'commits': [{'sha': 'b7f16356ea1091384047611da29258b9bcf2ff73',
#      'author': {'email': '124559883+RazorGazer@users.noreply.github.com',
#       'name': 'RazorGazer'},
#      'message': 'Delete style.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RazorGazer/Wireless-and-mobile-computing/commits/b7f16356ea1091384047611da29258b9bcf2ff73'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963372',
#   'type': 'PushEvent',
#   'actor': {'id': 96680996,
#    'login': 'ChemwenoKibet',
#    'display_login': 'ChemwenoKibet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ChemwenoKibet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96680996?'},
#   'repo': {'id': 598012512,
#    'name': 'ChemwenoKibet/phase-3-reading-error-messages',
#    'url': 'https://api.github.com/repos/ChemwenoKibet/phase-3-reading-error-messages'},
#   'payload': {'push_id': 12520990534,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7a4d4325b86b3ee686248e1c8fedb01a859ec359',
#    'before': '78a4d7572833a9628dede538cc370df063f66f50',
#    'commits': [{'sha': '7a4d4325b86b3ee686248e1c8fedb01a859ec359',
#      'author': {'email': 'chemwenokibet11@gmail.com', 'name': 'Ian'},
#      'message': 'Completed assignment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ChemwenoKibet/phase-3-reading-error-messages/commits/7a4d4325b86b3ee686248e1c8fedb01a859ec359'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963342',
#   'type': 'PushEvent',
#   'actor': {'id': 7045900,
#    'login': 'Bernardo-MG',
#    'display_login': 'Bernardo-MG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bernardo-MG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7045900?'},
#   'repo': {'id': 471439104,
#    'name': 'Bernardo-MG/spring-ws-basic-security-example',
#    'url': 'https://api.github.com/repos/Bernardo-MG/spring-ws-basic-security-example'},
#   'payload': {'push_id': 12520990516,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'f7ddcca873dc27748a272711a56cc37c2b7e2414',
#    'before': '5f1ded3eb44cde5da23964d838cf4b98d1588d51',
#    'commits': [{'sha': 'f7ddcca873dc27748a272711a56cc37c2b7e2414',
#      'author': {'email': 'programming@bernardo-mg.com', 'name': 'Bernardo-MG'},
#      'message': 'Removed reference to login path',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Bernardo-MG/spring-ws-basic-security-example/commits/f7ddcca873dc27748a272711a56cc37c2b7e2414'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963355',
#   'type': 'WatchEvent',
#   'actor': {'id': 36198012,
#    'login': 'elhadjx',
#    'display_login': 'elhadjx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elhadjx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36198012?'},
#   'repo': {'id': 47899501,
#    'name': 'vigneshv59/apertium-wol.jw.org-scraper',
#    'url': 'https://api.github.com/repos/vigneshv59/apertium-wol.jw.org-scraper'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963280',
#   'type': 'WatchEvent',
#   'actor': {'id': 30425119,
#    'login': 'phenge',
#    'display_login': 'phenge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phenge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30425119?'},
#   'repo': {'id': 307651482,
#    'name': 'net-byte/vtun',
#    'url': 'https://api.github.com/repos/net-byte/vtun'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963353',
#   'type': 'CreateEvent',
#   'actor': {'id': 122659846,
#    'login': 'thengeshera358',
#    'display_login': 'thengeshera358',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thengeshera358',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122659846?'},
#   'repo': {'id': 598033193,
#    'name': 'thengeshera358/media-querries-and-different-width',
#    'url': 'https://api.github.com/repos/thengeshera358/media-querries-and-different-width'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963286',
#   'type': 'PushEvent',
#   'actor': {'id': 43162188,
#    'login': 'durumi99',
#    'display_login': 'durumi99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/durumi99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43162188?'},
#   'repo': {'id': 320749511,
#    'name': 'durumi99/baekjoon',
#    'url': 'https://api.github.com/repos/durumi99/baekjoon'},
#   'payload': {'push_id': 12520990501,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8c4bc5da8944b7ef8dea2ee6e98d8efbbfa15be4',
#    'before': '46a5d79b8d1ddef714835c3955156e36d8bf788b',
#    'commits': [{'sha': '8c4bc5da8944b7ef8dea2ee6e98d8efbbfa15be4',
#      'author': {'email': '43162188+durumi99@users.noreply.github.com',
#       'name': 'durumi99'},
#      'message': '[level 2] Title: 재구매가 일어난 상품과 회원 리스트 구하기, Time: 0.00 ms, Memory: 0.0 MB -BaekjoonHub',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/durumi99/baekjoon/commits/8c4bc5da8944b7ef8dea2ee6e98d8efbbfa15be4'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963387',
#   'type': 'DeleteEvent',
#   'actor': {'id': 4134361,
#    'login': 'ozonelmy',
#    'display_login': 'ozonelmy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ozonelmy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4134361?'},
#   'repo': {'id': 298948454,
#    'name': 'ozonelmy/Hippy',
#    'url': 'https://api.github.com/repos/ozonelmy/Hippy'},
#   'payload': {'ref': 'bugfix/engine_remove',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963364',
#   'type': 'CreateEvent',
#   'actor': {'id': 74635296,
#    'login': 'sthmu',
#    'display_login': 'sthmu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sthmu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74635296?'},
#   'repo': {'id': 598033200,
#    'name': 'sthmu/damned',
#    'url': 'https://api.github.com/repos/sthmu/damned'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'This is a git hub test',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963304',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 519576283,
#    'name': 'easimon/azure-builtin-roles',
#    'url': 'https://api.github.com/repos/easimon/azure-builtin-roles'},
#   'payload': {'push_id': 12520990520,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b99b137845d948e6a8ad3da085bcc199d0c65041',
#    'before': '8cbf38a1aef9336002e00c4b8ea354ab6ec90c43',
#    'commits': [{'sha': 'b99b137845d948e6a8ad3da085bcc199d0c65041',
#      'author': {'email': 'azure-roles-github@noreply',
#       'name': 'azure-roles-github-actions[bot]'},
#      'message': 'Azure Built-In Role modified: Azure Center for SAP solutions administrator',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/easimon/azure-builtin-roles/commits/b99b137845d948e6a8ad3da085bcc199d0c65041'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963329',
#   'type': 'WatchEvent',
#   'actor': {'id': 124565256,
#    'login': 'Michiokaku390',
#    'display_login': 'Michiokaku390',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Michiokaku390',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124565256?'},
#   'repo': {'id': 545787957,
#    'name': 'Ramenaru/TopDown2D',
#    'url': 'https://api.github.com/repos/Ramenaru/TopDown2D'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963316',
#   'type': 'PushEvent',
#   'actor': {'id': 32507116,
#    'login': 'Thomas-Malh',
#    'display_login': 'Thomas-Malh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Thomas-Malh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32507116?'},
#   'repo': {'id': 478275335,
#    'name': 'Thomas-Malh/Thomas-Malh',
#    'url': 'https://api.github.com/repos/Thomas-Malh/Thomas-Malh'},
#   'payload': {'push_id': 12520990519,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1910f27b88832aa0f98ccf9fcd9dc3e7da583d5d',
#    'before': '99514374f8c84feebf60b553d60049cc5ac12de4',
#    'commits': [{'sha': '1910f27b88832aa0f98ccf9fcd9dc3e7da583d5d',
#      'author': {'email': 'ubuntu@knm.red', 'name': 'ubuntu'},
#      'message': 'Mon 06 Feb 2023 09:54:02 AM CET',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Thomas-Malh/Thomas-Malh/commits/1910f27b88832aa0f98ccf9fcd9dc3e7da583d5d'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963262',
#   'type': 'PushEvent',
#   'actor': {'id': 120321353,
#    'login': 'DavidKim1995',
#    'display_login': 'DavidKim1995',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DavidKim1995',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120321353?'},
#   'repo': {'id': 596185721,
#    'name': 'DavidKim1995/cone',
#    'url': 'https://api.github.com/repos/DavidKim1995/cone'},
#   'payload': {'push_id': 12520990481,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1eb401981c3d8545b8d7c3186ca590b6dd38b087',
#    'before': 'c12322ea865c78481f19e1bf60e095934bd69bcc',
#    'commits': [{'sha': '1eb401981c3d8545b8d7c3186ca590b6dd38b087',
#      'author': {'email': '120321353+DavidKim1995@users.noreply.github.com',
#       'name': 'DavidKim1995'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DavidKim1995/cone/commits/1eb401981c3d8545b8d7c3186ca590b6dd38b087'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'},
#  {'id': '26890963282',
#   'type': 'WatchEvent',
#   'actor': {'id': 36198012,
#    'login': 'elhadjx',
#    'display_login': 'elhadjx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elhadjx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36198012?'},
#   'repo': {'id': 29411169,
#    'name': 'vigneshv59/apertium-html-tools',
#    'url': 'https://api.github.com/repos/vigneshv59/apertium-html-tools'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:54:04Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# [{'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008800aac31001185ed07',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-06T21:20:03.505Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008630aac31001185ed01',
#   'user': '58e007480aac31001185ecef',
#   'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-02-07T21:20:02.903Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e00a090aac31001185ed16',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-02-11T21:20:03.745Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e009390aac31001185ed10',
#   'user': '58e007480aac31001185ecef',
#   'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-04T21:20:02.979Z',
#   'deleted': False,
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   '_id': '58e008780aac31001185ed05',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'type': 'cat',
#   'createdAt': '2018-03-29T20:20:03.844Z',
#   'deleted': False,
#   'used': False}]

# %%
import requests
r = requests.get('https://data.wra.gov.tw/Service/OpenData.aspx?format=json&id=2D09DB8B-6A1B-485E-88B5-923A462F475C')
json.loads(r.text)
# Out:
# {'RealtimeWaterLevel_OPENDATA': [{'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1010H007',
#    'WaterLevel': '108.68'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H001',
#    'WaterLevel': '684.32'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H002',
#    'WaterLevel': '530.67'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H041',
#    'WaterLevel': '829.96'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H043',
#    'WaterLevel': '439.13'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H048',
#    'WaterLevel': '28.30'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H049',
#    'WaterLevel': '22.20'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H054',
#    'WaterLevel': '246.79'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H058',
#    'WaterLevel': '5.01'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H066',
#    'WaterLevel': '2.05'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H076',
#    'WaterLevel': '135.42'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H082',
#    'WaterLevel': '6.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H089',
#    'WaterLevel': '57.22'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H095',
#    'WaterLevel': '109.74'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H096',
#    'WaterLevel': '170.82'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H097',
#    'WaterLevel': '172.03'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H098',
#    'WaterLevel': '174.67'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': '263.71'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H101',
#    'WaterLevel': '182.05'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H102',
#    'WaterLevel': '209.15'},
#   {'RecordTime': '2023-02-06T17:05:00',
#    'StationIdentifier': '1140H105',
#    'WaterLevel': '0.20'},
#   {'RecordTime': '2023-02-06T17:05:00',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': '49.11'},
#   {'RecordTime': '2023-02-06T17:05:00',
#    'StationIdentifier': '1140H107',
#    'WaterLevel': '2.55'},
#   {'RecordTime': '2023-02-06T17:05:00',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': '12.24'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H109',
#    'WaterLevel': '48.84'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H110',
#    'WaterLevel': '42.58'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H126',
#    'WaterLevel': '80.39'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H127',
#    'WaterLevel': '33.16'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H131',
#    'WaterLevel': '345.21'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H132',
#    'WaterLevel': '9.33'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H133',
#    'WaterLevel': '15.97'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1140H134',
#    'WaterLevel': '20.55'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1270H001',
#    'WaterLevel': '22.57'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1280H001',
#    'WaterLevel': '71.74'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': '41.23'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1290H004',
#    'WaterLevel': '115.78'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1290H006',
#    'WaterLevel': '66.76'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1290H007',
#    'WaterLevel': '12.86'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H013',
#    'WaterLevel': '247.14'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H014',
#    'WaterLevel': '208.97'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H016',
#    'WaterLevel': '100.66'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H017',
#    'WaterLevel': '27.16'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H018',
#    'WaterLevel': '96.65'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H019',
#    'WaterLevel': '86.35'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H020',
#    'WaterLevel': '251.71'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H021',
#    'WaterLevel': '-0.83'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': '-1.22'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H023',
#    'WaterLevel': '52.81'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1300H024',
#    'WaterLevel': '28.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1310H001',
#    'WaterLevel': '12.86'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1310H002',
#    'WaterLevel': '1.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1320H001',
#    'WaterLevel': '2.77'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1320H002',
#    'WaterLevel': '17.60'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H008',
#    'WaterLevel': '38.09'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H009',
#    'WaterLevel': '175.39'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H010',
#    'WaterLevel': '0.73'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': '7.45'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H012',
#    'WaterLevel': '247.09'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H013',
#    'WaterLevel': '246.97'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': '-0.38'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': '50.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1340H016',
#    'WaterLevel': '-0.54'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': '169.80'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H012',
#    'WaterLevel': '12.41'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': '95.50'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H017',
#    'WaterLevel': '244.37'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': '282.17'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H019',
#    'WaterLevel': '33.66'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': '220.82'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H021',
#    'WaterLevel': '320.27'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H022',
#    'WaterLevel': '253.91'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H023',
#    'WaterLevel': '256.28'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': '259.68'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H025',
#    'WaterLevel': '0.63'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H026',
#    'WaterLevel': '30.40'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': '146.44'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H028',
#    'WaterLevel': '232.78'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': '175.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H030',
#    'WaterLevel': '57.04'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': '-0.59'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H008',
#    'WaterLevel': '479.12'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': '189.82'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H012',
#    'WaterLevel': '598.84'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': '622.07'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H018',
#    'WaterLevel': '55.00'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': '310.33'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1400H020',
#    'WaterLevel': '321.04'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': '53.99'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H052',
#    'WaterLevel': '428.81'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': '472.88'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': '702.37'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': '319.30'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H056',
#    'WaterLevel': '195.55'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': '637.30'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': '440.41'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H025',
#    'WaterLevel': '9.32'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H028',
#    'WaterLevel': '23.18'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': '50.91'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H030',
#    'WaterLevel': '84.66'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H032',
#    'WaterLevel': '336.68'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': '380.98'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H038',
#    'WaterLevel': '75.21'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': '19.19'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H044',
#    'WaterLevel': '139.01'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': '91.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H046',
#    'WaterLevel': '111.08'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H048',
#    'WaterLevel': '164.43'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': '95.67'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H052',
#    'WaterLevel': '172.15'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H053',
#    'WaterLevel': '38.38'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': '48.47'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H055',
#    'WaterLevel': '77.91'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': '78.42'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H057',
#    'WaterLevel': '31.49'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': '82.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H060',
#    'WaterLevel': '19.86'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1430H061',
#    'WaterLevel': '24.92'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': '471.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H050',
#    'WaterLevel': '154.87'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H057',
#    'WaterLevel': '88.91'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': '12.01'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H063',
#    'WaterLevel': '264.48'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H064',
#    'WaterLevel': '265.33'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': '18.97'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510h075',
#    'WaterLevel': '346.04'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H076',
#    'WaterLevel': '4.67'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': '186.72'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': '1069.51'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H081',
#    'WaterLevel': '229.08'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': '754.48'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H083',
#    'WaterLevel': '115.75'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': '143.37'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H085',
#    'WaterLevel': '279.28'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': '317.35'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H087',
#    'WaterLevel': '428.69'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': '140.90'},
#   {'RecordTime': '2023-01-24T19:30:00',
#    'StationIdentifier': '1510H089',
#    'WaterLevel': '860.84'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1510H090',
#    'WaterLevel': '1027.84'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1510H091',
#    'WaterLevel': '826.31'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': '78.19'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': '0.42'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H014',
#    'WaterLevel': '7.62'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': '12.57'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': '26.88'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H031',
#    'WaterLevel': '9.88'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': '22.59'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': '23.36'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H035',
#    'WaterLevel': '87.07'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H036',
#    'WaterLevel': '0.03'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': '30.98'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H038',
#    'WaterLevel': '54.66'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': '38.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H011',
#    'WaterLevel': '0.34'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': '0.50'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': '26.44'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H016',
#    'WaterLevel': '12.34'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': '15.61'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1550H018',
#    'WaterLevel': '0.08'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': '224.11'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H007',
#    'WaterLevel': '23.45'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': '19.47'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H013',
#    'WaterLevel': '9.42'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H015',
#    'WaterLevel': '22.54'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': '25.72'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': '21.28'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H020',
#    'WaterLevel': '35.49'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': '1.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': '0.24'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H012',
#    'WaterLevel': '2.78'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': '22.32'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H015',
#    'WaterLevel': '-0.15'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': '11.70'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H018',
#    'WaterLevel': '-0.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H019',
#    'WaterLevel': '14.75'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1590H020',
#    'WaterLevel': '9.72'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': '39.75'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H013',
#    'WaterLevel': '15.50'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': '9.60'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': '35.84'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': '0.17'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': '69.65'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H025',
#    'WaterLevel': '2.21'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H026',
#    'WaterLevel': '45.09'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': '26.33'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H028',
#    'WaterLevel': '9.96'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H029',
#    'WaterLevel': '4.36'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': '2.30'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H031',
#    'WaterLevel': '0.37'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': '0.06'},
#   {'RecordTime': '2023-02-06T16:20:00',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': '-0.16'},
#   {'RecordTime': '2023-02-06T16:40:00',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': '278.07'},
#   {'RecordTime': '2023-02-06T16:40:00',
#    'StationIdentifier': '1630H035',
#    'WaterLevel': '402.08'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': '65.32'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H037',
#    'WaterLevel': '9.33'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': '2.31'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H006',
#    'WaterLevel': '0.95'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': '0.26'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H011',
#    'WaterLevel': '0.31'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': '5.19'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': '0.27'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H016',
#    'WaterLevel': '24.48'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H017',
#    'WaterLevel': '0.34'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1650H018',
#    'WaterLevel': '0.24'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': '5.05'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1660H010',
#    'WaterLevel': '7.30'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': '1.40'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': '0.38'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': '1.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1670H003',
#    'WaterLevel': '0.50'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': '2.96'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1680H004',
#    'WaterLevel': '1.13'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': '0.40'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': '106.15'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': '21.48'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H045',
#    'WaterLevel': '3.84'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': '43.09'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H058',
#    'WaterLevel': '114.09'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': '266.15'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H062',
#    'WaterLevel': '41.50'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H065',
#    'WaterLevel': '90.89'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': '137.15'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H067',
#    'WaterLevel': '396.94'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': '8.49'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H069',
#    'WaterLevel': '138.97'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': '226.02'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H071',
#    'WaterLevel': '35.02'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': '251.45'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H074',
#    'WaterLevel': '245.64'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': '93.74'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H076',
#    'WaterLevel': '57.85'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': '740.69'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H079',
#    'WaterLevel': '548.29'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1730H081',
#    'WaterLevel': '345.67'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': '3.93'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1740H007',
#    'WaterLevel': '-999998.00'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': '1.21'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1740H009',
#    'WaterLevel': '34.69'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '1740H010',
#    'WaterLevel': '47.37'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': '6.75'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1850H004',
#    'WaterLevel': '72.22'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': '22.02'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '1850H006',
#    'WaterLevel': '68.12'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H007',
#    'WaterLevel': '157.00'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H011',
#    'WaterLevel': '25.14'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H020',
#    'WaterLevel': '314.80'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H021',
#    'WaterLevel': '-999998.00'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': '160.72'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H025',
#    'WaterLevel': '206.86'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': '106.42'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': '277.62'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': '146.40'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H004',
#    'WaterLevel': '192.29'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H016',
#    'WaterLevel': '168.21'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': '59.47'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': '124.34'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H019',
#    'WaterLevel': '155.00'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': '261.44'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2370H028',
#    'WaterLevel': '209.10'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H018',
#    'WaterLevel': '154.27'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': '110.20'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H024',
#    'WaterLevel': '4.33'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': '164.28'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H037',
#    'WaterLevel': '133.64'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': '78.65'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2420H046',
#    'WaterLevel': '35.66'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': '29.02'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H006',
#    'WaterLevel': '2.41'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': '363.28'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': '4.43'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': '0.70'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H022',
#    'WaterLevel': '193.65'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': '13.13'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H024',
#    'WaterLevel': '199.63'},
#   {'RecordTime': '2023-02-06T17:00:00',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': '2.32'},
#   {'RecordTime': '2023-02-06T16:50:00',
#    'StationIdentifier': '2560H026',
#    'WaterLevel': '365.78'}]}
