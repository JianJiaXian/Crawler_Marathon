# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"26890895305","type":"WatchEvent","actor":{"id":36198012,"login":"elhadjx","display_login":"elhadjx","gravatar_id":"","url":"https://api.github.com/users/elhadjx","avatar_url":"https://avatars.githubusercontent.com/u/36198012?"},"repo":{"id":153632721,"name":"yidemir/Security","url":"https://api.github.com/repos/yidemir/Security"},"payload":{"action":"started"},"public":true,"created_at":"2023-02-06T08:50:56Z"},{"id":"26890895316","type":"CreateEvent","actor":{"id":68299464,"login":"shen320","display_login":"shen320","gravatar_id":"","url":"https://api.github.com/users/shen320","avatar_url":"https://avatars.githubusercontent.com/u/68299464?"},"repo":{"id":598029185,"name":"shen320/Padavan-build","url":"https://api.github.com/repos/shen320/Padavan-build"},"payload":{"ref":"1650","ref_type":"tag","master_branch":"master","description":"Padavan 自动编译","pusher_type":"user"},"public":true,"created_at":"2023-02-06T08:50:56Z"},{"id":"26890895297","type":"PushEvent","actor":{"id":65674790,"login":"alfarabi-mazhit","display_login":"alfarabi-mazhit","gravatar_id":"","url":"https://api.github.com/users/alfarabi-mazhit","avatar_url":"https://avatars.githubusercontent.com/u/65674790?"},"repo":{"id":598019548,"name":"alfarabi-mazhit/home-proj","url":"https://api.github.com/repos/alfarabi-mazhit/home-proj"},"payload":{"push_id":12520958432,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"f646a25b9b075717e2697c90a53b534d528808ac","before":"fa23460ba0f3165afa169f6b7573ed0fe2d4fed1","commits":[{"sha":"f646a25b9b075717e2697c90a53b534d528808ac","author":{"email":"a-mazhit@mail.ru","name":"Mazhit Alfarabi"},"message":"team members img","distinct":true,"url":"https://api.github.com/repos/alfarabi-mazhit/home-proj/commits/f646a25b9b075717e2697c90a53b534d528808ac"}]},"public":true,"created_at":"2023-02-06T08:50:56Z"},{"id":"26890895301","type":"CommitCommentEvent","actor":{"id":35613825,"login":"vercel[bot]","display_login":"vercel","gravatar_id":"","url":"https://api.github.com/users/vercel[bot]","avatar_url":"https://avatars.githubusercontent.com/u/35613825?"},"repo":{"id":597440509,"name":"AleXLaeR/Amazon-Clone","url":"https://api.github.com/repos/AleXLaeR/Amazon-Clone"},"payload":{"comment":{"url":"https://api.github.com/repos/AleXLaeR/Amazon-Clone/comments/99452800","html_url":"https://github.com/AleXLaeR/Amazon-Clone/commit/decbbd9616e2220aef98f00ed77829223f35d00a#commitcomment-99452800","id":99452800,"node_id":"CC_kwDOI5w3_c4F7YeA","user":{"login":"vercel[bot]","id":35613825,"node_id":"MDM6Qm90MzU2MTM4MjU=","avatar_url":"https://avatars.githubusercontent.com/in/8329?v=4","gravatar_id":"","url":"https://api.github.com/users/vercel%5Bbot%5D","html_url":"https://github.com/apps/vercel","followers_url":"https://api.github.com/users/vercel%5Bbot%5D/followers","following_url":"https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/vercel%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/vercel%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/vercel%5Bbot%5D/repos","events_url":"https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/vercel%5Bbot%5D/received_events","type":"Bot","site_admin":false},"position":null,"line":null,"path":null,"commit_id":"decbbd9616e2220aef98f00ed77829223f35d00a","created_at":"2023-02-06T08:50:56Z","updated_at":"2023-02-06T08:50:56Z","author_association":"NONE","body":"Successfully deployed to the following URLs:\\n\\n## amazon-clone – ./\\n\\n[amazon-clone-git-main-alexlaer.vercel.app](https://amazon-clone-git-main-alexlaer.vercel.app)  \\n[amazon-clone-alexlaer.vercel.app](https://amazon-clone-alexlaer.vercel.app)  \\n[amazon-clone-seven-jet.vercel.app](https://amazon-clone-seven-jet.vercel.app) ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '26890895305',
#   'type': 'WatchEvent',
#   'actor': {'id': 36198012,
#    'login': 'elhadjx',
#    'display_login': 'elhadjx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elhadjx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36198012?'},
#   'repo': {'id': 153632721,
#    'name': 'yidemir/Security',
#    'url': 'https://api.github.com/repos/yidemir/Security'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895316',
#   'type': 'CreateEvent',
#   'actor': {'id': 68299464,
#    'login': 'shen320',
#    'display_login': 'shen320',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shen320',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68299464?'},
#   'repo': {'id': 598029185,
#    'name': 'shen320/Padavan-build',
#    'url': 'https://api.github.com/repos/shen320/Padavan-build'},
#   'payload': {'ref': '1650',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Padavan 自动编译',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895297',
#   'type': 'PushEvent',
#   'actor': {'id': 65674790,
#    'login': 'alfarabi-mazhit',
#    'display_login': 'alfarabi-mazhit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alfarabi-mazhit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65674790?'},
#   'repo': {'id': 598019548,
#    'name': 'alfarabi-mazhit/home-proj',
#    'url': 'https://api.github.com/repos/alfarabi-mazhit/home-proj'},
#   'payload': {'push_id': 12520958432,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f646a25b9b075717e2697c90a53b534d528808ac',
#    'before': 'fa23460ba0f3165afa169f6b7573ed0fe2d4fed1',
#    'commits': [{'sha': 'f646a25b9b075717e2697c90a53b534d528808ac',
#      'author': {'email': 'a-mazhit@mail.ru', 'name': 'Mazhit Alfarabi'},
#      'message': 'team members img',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alfarabi-mazhit/home-proj/commits/f646a25b9b075717e2697c90a53b534d528808ac'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895301',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 597440509,
#    'name': 'AleXLaeR/Amazon-Clone',
#    'url': 'https://api.github.com/repos/AleXLaeR/Amazon-Clone'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/AleXLaeR/Amazon-Clone/comments/99452800',
#     'html_url': 'https://github.com/AleXLaeR/Amazon-Clone/commit/decbbd9616e2220aef98f00ed77829223f35d00a#commitcomment-99452800',
#     'id': 99452800,
#     'node_id': 'CC_kwDOI5w3_c4F7YeA',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': 'decbbd9616e2220aef98f00ed77829223f35d00a',
#     'created_at': '2023-02-06T08:50:56Z',
#     'updated_at': '2023-02-06T08:50:56Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## amazon-clone – ./\n\n[amazon-clone-git-main-alexlaer.vercel.app](https://amazon-clone-git-main-alexlaer.vercel.app)  \n[amazon-clone-alexlaer.vercel.app](https://amazon-clone-alexlaer.vercel.app)  \n[amazon-clone-seven-jet.vercel.app](https://amazon-clone-seven-jet.vercel.app)',
#     'reactions': {'url': 'https://api.github.com/repos/AleXLaeR/Amazon-Clone/comments/99452800/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895257',
#   'type': 'PushEvent',
#   'actor': {'id': 119910615,
#    'login': 'happyfish2024',
#    'display_login': 'happyfish2024',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/happyfish2024',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119910615?'},
#   'repo': {'id': 575386595,
#    'name': 'happyfish2024/mins',
#    'url': 'https://api.github.com/repos/happyfish2024/mins'},
#   'payload': {'push_id': 12520958452,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6f28788787c8224a4e2dfe80f409901e618d8297',
#    'before': 'dd0e5eb086670d702483d723796722e822017a4b',
#    'commits': [{'sha': '6f28788787c8224a4e2dfe80f409901e618d8297',
#      'author': {'email': '119910615+happyfish2024@users.noreply.github.com',
#       'name': 'happyfish2024'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/happyfish2024/mins/commits/6f28788787c8224a4e2dfe80f409901e618d8297'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895230',
#   'type': 'WatchEvent',
#   'actor': {'id': 36198012,
#    'login': 'elhadjx',
#    'display_login': 'elhadjx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elhadjx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36198012?'},
#   'repo': {'id': 35236694,
#    'name': 'yidemir/Pratik-PDO',
#    'url': 'https://api.github.com/repos/yidemir/Pratik-PDO'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895199',
#   'type': 'PushEvent',
#   'actor': {'id': 56629378,
#    'login': 'xiaodongxier',
#    'display_login': 'xiaodongxier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xiaodongxier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56629378?'},
#   'repo': {'id': 595410788,
#    'name': 'xiaodongxier/xiaodongxier.github.io',
#    'url': 'https://api.github.com/repos/xiaodongxier/xiaodongxier.github.io'},
#   'payload': {'push_id': 12520958392,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c7afd7432489b7d1b9589885d2c344615ba62066',
#    'before': '546ce70a2bb0c0531dbb44a3dfa01a62c29b6565',
#    'commits': [{'sha': 'c7afd7432489b7d1b9589885d2c344615ba62066',
#      'author': {'email': 'xiaodongxier@gmail.com', 'name': 'xiaodongxier'},
#      'message': 'Site updated: 2023-02-06 16:50:51',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xiaodongxier/xiaodongxier.github.io/commits/c7afd7432489b7d1b9589885d2c344615ba62066'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'},
#  {'id': '26890895248',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 121870,
#    'login': 'nicosomb',
#    'display_login': 'nicosomb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nicosomb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121870?'},
#   'repo': {'id': 17974736,
#    'name': 'PrestaShop/blockwishlist',
#    'url': 'https://api.github.com/repos/PrestaShop/blockwishlist'},
#   'payload': {'action': 'closed',
#    'number': 206,
#    'pull_request': {'url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206',
#     'id': 1228467241,
#     'node_id': 'PR_kwDOARJF0M5JOOwp',
#     'html_url': 'https://github.com/PrestaShop/blockwishlist/pull/206',
#     'diff_url': 'https://github.com/PrestaShop/blockwishlist/pull/206.diff',
#     'patch_url': 'https://github.com/PrestaShop/blockwishlist/pull/206.patch',
#     'issue_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/206',
#     'number': 206,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump http-cache-semantics from 4.1.0 to 4.1.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [http-cache-semantics](https://github.com/kornelski/http-cache-semantics) from 4.1.0 to 4.1.1.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/24496504352199caf360d1b4d4a01efdc8a7249e"><code>2449650</code></a> Update mocha</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/560b2d8ef452bbba20ffed69dc155d63ac757b74"><code>560b2d8</code></a> Don\'t use regex to trim whitespace</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/b1bdb92638426fab978f31e1330b6833015cabf0"><code>b1bdb92</code></a> Remove linting package zoo</li>\n<li><a href="https://github.com/kornelski/http-cache-semantics/commit/c20dc7eeca608339143857953ee7ed9343fe6d3d"><code>c20dc7e</code></a> Cache 308</li>\n<li>See full diff in <a href="https://github.com/kornelski/http-cache-semantics/compare/v4.1.0...v4.1.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=http-cache-semantics&package-manager=npm_and_yarn&previous-version=4.1.0&new-version=4.1.1)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/PrestaShop/blockwishlist/network/alerts).\n\n</details>',
#     'created_at': '2023-02-03T17:38:50Z',
#     'updated_at': '2023-02-06T08:50:55Z',
#     'closed_at': '2023-02-06T08:50:54Z',
#     'merged_at': '2023-02-06T08:50:54Z',
#     'merge_commit_sha': 'c142fc31012da952a7a8c5b4a04d19ff32456f08',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2806248608,
#       'node_id': 'MDU6TGFiZWwyODA2MjQ4NjA4',
#       'url': 'https://api.github.com/repos/PrestaShop/blockwishlist/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': {'url': 'https://api.github.com/repos/PrestaShop/blockwishlist/milestones/6',
#      'html_url': 'https://github.com/PrestaShop/blockwishlist/milestone/6',
#      'labels_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/milestones/6/labels',
#      'id': 8548661,
#      'node_id': 'MI_kwDOARJF0M4AgnE1',
#      'number': 6,
#      'title': '2.1.3',
#      'description': None,
#      'creator': {'login': 'kpodemski',
#       'id': 2137763,
#       'node_id': 'MDQ6VXNlcjIxMzc3NjM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2137763?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kpodemski',
#       'html_url': 'https://github.com/kpodemski',
#       'followers_url': 'https://api.github.com/users/kpodemski/followers',
#       'following_url': 'https://api.github.com/users/kpodemski/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kpodemski/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kpodemski/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kpodemski/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kpodemski/orgs',
#       'repos_url': 'https://api.github.com/users/kpodemski/repos',
#       'events_url': 'https://api.github.com/users/kpodemski/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kpodemski/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 0,
#      'closed_issues': 9,
#      'state': 'open',
#      'created_at': '2022-10-17T11:39:58Z',
#      'updated_at': '2023-02-06T08:50:55Z',
#      'due_on': None,
#      'closed_at': None},
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206/commits',
#     'review_comments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206/comments',
#     'review_comment_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/206/comments',
#     'statuses_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/statuses/d94479ffc1d5392c6a602227b3841c04f8223d80',
#     'head': {'label': 'PrestaShop:dependabot/npm_and_yarn/http-cache-semantics-4.1.1',
#      'ref': 'dependabot/npm_and_yarn/http-cache-semantics-4.1.1',
#      'sha': 'd94479ffc1d5392c6a602227b3841c04f8223d80',
#      'user': {'login': 'PrestaShop',
#       'id': 2815696,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MTU2OTY=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2815696?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/PrestaShop',
#       'html_url': 'https://github.com/PrestaShop',
#       'followers_url': 'https://api.github.com/users/PrestaShop/followers',
#       'following_url': 'https://api.github.com/users/PrestaShop/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/PrestaShop/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/PrestaShop/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/PrestaShop/subscriptions',
#       'organizations_url': 'https://api.github.com/users/PrestaShop/orgs',
#       'repos_url': 'https://api.github.com/users/PrestaShop/repos',
#       'events_url': 'https://api.github.com/users/PrestaShop/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/PrestaShop/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 17974736,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzk3NDczNg==',
#       'name': 'blockwishlist',
#       'full_name': 'PrestaShop/blockwishlist',
#       'private': False,
#       'owner': {'login': 'PrestaShop',
#        'id': 2815696,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MTU2OTY=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2815696?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/PrestaShop',
#        'html_url': 'https://github.com/PrestaShop',
#        'followers_url': 'https://api.github.com/users/PrestaShop/followers',
#        'following_url': 'https://api.github.com/users/PrestaShop/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/PrestaShop/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/PrestaShop/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/PrestaShop/subscriptions',
#        'organizations_url': 'https://api.github.com/users/PrestaShop/orgs',
#        'repos_url': 'https://api.github.com/users/PrestaShop/repos',
#        'events_url': 'https://api.github.com/users/PrestaShop/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/PrestaShop/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/PrestaShop/blockwishlist',
#       'description': "Adds a block containing the customer's wishlists.",
#       'fork': False,
#       'url': 'https://api.github.com/repos/PrestaShop/blockwishlist',
#       'forks_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/forks',
#       'keys_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/teams',
#       'hooks_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/hooks',
#       'issue_events_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/events',
#       'assignees_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/tags',
#       'blobs_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/languages',
#       'stargazers_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/stargazers',
#       'contributors_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/contributors',
#       'subscribers_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/subscribers',
#       'subscription_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/subscription',
#       'commits_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/merges',
#       'archive_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/downloads',
#       'issues_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/deployments',
#       'created_at': '2014-03-21T09:29:46Z',
#       'updated_at': '2023-01-31T16:33:36Z',
#       'pushed_at': '2023-02-06T08:50:53Z',
#       'git_url': 'git://github.com/PrestaShop/blockwishlist.git',
#       'ssh_url': 'git@github.com:PrestaShop/blockwishlist.git',
#       'clone_url': 'https://github.com/PrestaShop/blockwishlist.git',
#       'svn_url': 'https://github.com/PrestaShop/blockwishlist',
#       'homepage': 'https://www.prestashop-project.org/',
#       'size': 6165,
#       'stargazers_count': 37,
#       'watchers_count': 37,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 109,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'afl-3.0',
#        'name': 'Academic Free License v3.0',
#        'spdx_id': 'AFL-3.0',
#        'url': 'https://api.github.com/licenses/afl-3.0',
#        'node_id': 'MDc6TGljZW5zZTIy'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest', 'prestashop-module'],
#       'visibility': 'public',
#       'forks': 109,
#       'open_issues': 7,
#       'watchers': 37,
#       'default_branch': 'dev'}},
#     'base': {'label': 'PrestaShop:dev',
#      'ref': 'dev',
#      'sha': '949e331faab2ec6ccc9168f5cc3d0b4d941a6fe8',
#      'user': {'login': 'PrestaShop',
#       'id': 2815696,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MTU2OTY=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/2815696?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/PrestaShop',
#       'html_url': 'https://github.com/PrestaShop',
#       'followers_url': 'https://api.github.com/users/PrestaShop/followers',
#       'following_url': 'https://api.github.com/users/PrestaShop/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/PrestaShop/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/PrestaShop/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/PrestaShop/subscriptions',
#       'organizations_url': 'https://api.github.com/users/PrestaShop/orgs',
#       'repos_url': 'https://api.github.com/users/PrestaShop/repos',
#       'events_url': 'https://api.github.com/users/PrestaShop/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/PrestaShop/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 17974736,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzk3NDczNg==',
#       'name': 'blockwishlist',
#       'full_name': 'PrestaShop/blockwishlist',
#       'private': False,
#       'owner': {'login': 'PrestaShop',
#        'id': 2815696,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI4MTU2OTY=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/2815696?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/PrestaShop',
#        'html_url': 'https://github.com/PrestaShop',
#        'followers_url': 'https://api.github.com/users/PrestaShop/followers',
#        'following_url': 'https://api.github.com/users/PrestaShop/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/PrestaShop/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/PrestaShop/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/PrestaShop/subscriptions',
#        'organizations_url': 'https://api.github.com/users/PrestaShop/orgs',
#        'repos_url': 'https://api.github.com/users/PrestaShop/repos',
#        'events_url': 'https://api.github.com/users/PrestaShop/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/PrestaShop/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/PrestaShop/blockwishlist',
#       'description': "Adds a block containing the customer's wishlists.",
#       'fork': False,
#       'url': 'https://api.github.com/repos/PrestaShop/blockwishlist',
#       'forks_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/forks',
#       'keys_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/teams',
#       'hooks_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/hooks',
#       'issue_events_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/events',
#       'assignees_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/tags',
#       'blobs_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/languages',
#       'stargazers_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/stargazers',
#       'contributors_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/contributors',
#       'subscribers_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/subscribers',
#       'subscription_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/subscription',
#       'commits_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/merges',
#       'archive_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/downloads',
#       'issues_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/PrestaShop/blockwishlist/deployments',
#       'created_at': '2014-03-21T09:29:46Z',
#       'updated_at': '2023-01-31T16:33:36Z',
#       'pushed_at': '2023-02-06T08:50:53Z',
#       'git_url': 'git://github.com/PrestaShop/blockwishlist.git',
#       'ssh_url': 'git@github.com:PrestaShop/blockwishlist.git',
#       'clone_url': 'https://github.com/PrestaShop/blockwishlist.git',
#       'svn_url': 'https://github.com/PrestaShop/blockwishlist',
#       'homepage': 'https://www.prestashop-project.org/',
#       'size': 6165,
#       'stargazers_count': 37,
#       'watchers_count': 37,
#       'language': 'PHP',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 109,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'afl-3.0',
#        'name': 'Academic Free License v3.0',
#        'spdx_id': 'AFL-3.0',
#        'url': 'https://api.github.com/licenses/afl-3.0',
#        'node_id': 'MDc6TGljZW5zZTIy'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest', 'prestashop-module'],
#       'visibility': 'public',
#       'forks': 109,
#       'open_issues': 7,
#       'watchers': 37,
#       'default_branch': 'dev'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206'},
#      'html': {'href': 'https://github.com/PrestaShop/blockwishlist/pull/206'},
#      'issue': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/206'},
#      'comments': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/issues/206/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/pulls/206/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/PrestaShop/blockwishlist/statuses/d94479ffc1d5392c6a602227b3841c04f8223d80'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'nicosomb',
#      'id': 121870,
#      'node_id': 'MDQ6VXNlcjEyMTg3MA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/121870?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nicosomb',
#      'html_url': 'https://github.com/nicosomb',
#      'followers_url': 'https://api.github.com/users/nicosomb/followers',
#      'following_url': 'https://api.github.com/users/nicosomb/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nicosomb/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nicosomb/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nicosomb/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nicosomb/orgs',
#      'repos_url': 'https://api.github.com/users/nicosomb/repos',
#      'events_url': 'https://api.github.com/users/nicosomb/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nicosomb/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z',
#   'org': {'id': 2815696,
#    'login': 'PrestaShop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PrestaShop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2815696?'}},
#  {'id': '26890895205',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 10096906,
#    'login': 'dongsupark',
#    'display_login': 'dongsupark',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dongsupark',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10096906?'},
#   'repo': {'id': 123933407,
#    'name': 'flatcar/coreos-overlay',
#    'url': 'https://api.github.com/repos/flatcar/coreos-overlay'},
#   'payload': {'action': 'closed',
#    'number': 2422,
#    'pull_request': {'url': 'https://api.github.com/repos/flatcar/coreos-overlay/pulls/2422',
#     'id': 1226070439,
#     'node_id': 'PR_kwDOB2MS385JFFmn',
#     'html_url': 'https://github.com/flatcar/coreos-overlay/pull/2422',
#     'diff_url': 'https://github.com/flatcar/coreos-overlay/pull/2422.diff',
#     'patch_url': 'https://github.com/flatcar/coreos-overlay/pull/2422.patch',
#     'issue_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues/2422',
#     'number': 2422,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Upgrade Linux Kernel for main from 5.15.89 to 5.15.91',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Subject says it all.',
#     'created_at': '2023-02-02T07:16:56Z',
#     'updated_at': '2023-02-06T08:50:55Z',
#     'closed_at': '2023-02-06T08:50:55Z',
#     'merged_at': None,
#     'merge_commit_sha': 'f4fa9f61b7e005ad266fea6e9ff77c99278d31be',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2241199846,
#       'node_id': 'MDU6TGFiZWwyMjQxMTk5ODQ2',
#       'url': 'https://api.github.com/repos/flatcar/coreos-overlay/labels/main',
#       'name': 'main',
#       'color': 'b7931b',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/flatcar/coreos-overlay/pulls/2422/commits',
#     'review_comments_url': 'https://api.github.com/repos/flatcar/coreos-overlay/pulls/2422/comments',
#     'review_comment_url': 'https://api.github.com/repos/flatcar/coreos-overlay/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues/2422/comments',
#     'statuses_url': 'https://api.github.com/repos/flatcar/coreos-overlay/statuses/ad529944d1ebfe4d16e443581a5f37f31d4bf6a5',
#     'head': {'label': 'flatcar:linux-5.15.91-main',
#      'ref': 'linux-5.15.91-main',
#      'sha': 'ad529944d1ebfe4d16e443581a5f37f31d4bf6a5',
#      'user': {'login': 'flatcar',
#       'id': 36193555,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MTkzNTU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/36193555?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/flatcar',
#       'html_url': 'https://github.com/flatcar',
#       'followers_url': 'https://api.github.com/users/flatcar/followers',
#       'following_url': 'https://api.github.com/users/flatcar/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/flatcar/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/flatcar/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/flatcar/subscriptions',
#       'organizations_url': 'https://api.github.com/users/flatcar/orgs',
#       'repos_url': 'https://api.github.com/users/flatcar/repos',
#       'events_url': 'https://api.github.com/users/flatcar/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/flatcar/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 123933407,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjM5MzM0MDc=',
#       'name': 'coreos-overlay',
#       'full_name': 'flatcar/coreos-overlay',
#       'private': False,
#       'owner': {'login': 'flatcar',
#        'id': 36193555,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MTkzNTU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/36193555?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/flatcar',
#        'html_url': 'https://github.com/flatcar',
#        'followers_url': 'https://api.github.com/users/flatcar/followers',
#        'following_url': 'https://api.github.com/users/flatcar/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/flatcar/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/flatcar/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/flatcar/subscriptions',
#        'organizations_url': 'https://api.github.com/users/flatcar/orgs',
#        'repos_url': 'https://api.github.com/users/flatcar/repos',
#        'events_url': 'https://api.github.com/users/flatcar/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/flatcar/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/flatcar/coreos-overlay',
#       'description': 'package build scripts for Flatcar Container Linux, with custom overlay on kinvolk/portage-stable',
#       'fork': False,
#       'url': 'https://api.github.com/repos/flatcar/coreos-overlay',
#       'forks_url': 'https://api.github.com/repos/flatcar/coreos-overlay/forks',
#       'keys_url': 'https://api.github.com/repos/flatcar/coreos-overlay/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/flatcar/coreos-overlay/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/flatcar/coreos-overlay/teams',
#       'hooks_url': 'https://api.github.com/repos/flatcar/coreos-overlay/hooks',
#       'issue_events_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/flatcar/coreos-overlay/events',
#       'assignees_url': 'https://api.github.com/repos/flatcar/coreos-overlay/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/flatcar/coreos-overlay/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/flatcar/coreos-overlay/tags',
#       'blobs_url': 'https://api.github.com/repos/flatcar/coreos-overlay/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/flatcar/coreos-overlay/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/flatcar/coreos-overlay/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/flatcar/coreos-overlay/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/flatcar/coreos-overlay/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/flatcar/coreos-overlay/languages',
#       'stargazers_url': 'https://api.github.com/repos/flatcar/coreos-overlay/stargazers',
#       'contributors_url': 'https://api.github.com/repos/flatcar/coreos-overlay/contributors',
#       'subscribers_url': 'https://api.github.com/repos/flatcar/coreos-overlay/subscribers',
#       'subscription_url': 'https://api.github.com/repos/flatcar/coreos-overlay/subscription',
#       'commits_url': 'https://api.github.com/repos/flatcar/coreos-overlay/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/flatcar/coreos-overlay/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/flatcar/coreos-overlay/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/flatcar/coreos-overlay/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/flatcar/coreos-overlay/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/flatcar/coreos-overlay/merges',
#       'archive_url': 'https://api.github.com/repos/flatcar/coreos-overlay/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/flatcar/coreos-overlay/downloads',
#       'issues_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/flatcar/coreos-overlay/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/flatcar/coreos-overlay/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/flatcar/coreos-overlay/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/flatcar/coreos-overlay/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/flatcar/coreos-overlay/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/flatcar/coreos-overlay/deployments',
#       'created_at': '2018-03-05T14:42:45Z',
#       'updated_at': '2023-01-31T16:57:39Z',
#       'pushed_at': '2023-02-06T08:50:26Z',
#       'git_url': 'git://github.com/flatcar/coreos-overlay.git',
#       'ssh_url': 'git@github.com:flatcar/coreos-overlay.git',
#       'clone_url': 'https://github.com/flatcar/coreos-overlay.git',
#       'svn_url': 'https://github.com/flatcar/coreos-overlay',
#       'homepage': 'https://github.com/flatcar-linux/flatcar/issues',
#       'size': 26730,
#       'stargazers_count': 25,
#       'watchers_count': 25,
#       'language': 'Shell',
#       'has_issues': False,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 34,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 19,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['flatcar', 'hacktoberfest', 'portage'],
#       'visibility': 'public',
#       'forks': 34,
#       'open_issues': 19,
#       'watchers': 25,
#       'default_branch': 'main'}},
#     'base': {'label': 'flatcar:main',
#      'ref': 'main',
#      'sha': '1576eeaed3c9c91469b92f13b791acb83e3db7a1',
#      'user': {'login': 'flatcar',
#       'id': 36193555,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MTkzNTU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/36193555?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/flatcar',
#       'html_url': 'https://github.com/flatcar',
#       'followers_url': 'https://api.github.com/users/flatcar/followers',
#       'following_url': 'https://api.github.com/users/flatcar/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/flatcar/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/flatcar/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/flatcar/subscriptions',
#       'organizations_url': 'https://api.github.com/users/flatcar/orgs',
#       'repos_url': 'https://api.github.com/users/flatcar/repos',
#       'events_url': 'https://api.github.com/users/flatcar/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/flatcar/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 123933407,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjM5MzM0MDc=',
#       'name': 'coreos-overlay',
#       'full_name': 'flatcar/coreos-overlay',
#       'private': False,
#       'owner': {'login': 'flatcar',
#        'id': 36193555,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2MTkzNTU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/36193555?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/flatcar',
#        'html_url': 'https://github.com/flatcar',
#        'followers_url': 'https://api.github.com/users/flatcar/followers',
#        'following_url': 'https://api.github.com/users/flatcar/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/flatcar/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/flatcar/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/flatcar/subscriptions',
#        'organizations_url': 'https://api.github.com/users/flatcar/orgs',
#        'repos_url': 'https://api.github.com/users/flatcar/repos',
#        'events_url': 'https://api.github.com/users/flatcar/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/flatcar/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/flatcar/coreos-overlay',
#       'description': 'package build scripts for Flatcar Container Linux, with custom overlay on kinvolk/portage-stable',
#       'fork': False,
#       'url': 'https://api.github.com/repos/flatcar/coreos-overlay',
#       'forks_url': 'https://api.github.com/repos/flatcar/coreos-overlay/forks',
#       'keys_url': 'https://api.github.com/repos/flatcar/coreos-overlay/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/flatcar/coreos-overlay/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/flatcar/coreos-overlay/teams',
#       'hooks_url': 'https://api.github.com/repos/flatcar/coreos-overlay/hooks',
#       'issue_events_url': 'https://api.github.com/repos/flatcar/coreos-overlay/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/flatcar/coreos-overlay/events',
#       'assignees_url': 'https://api.github.com/repos/flatcar/coreos-overlay/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/flatcar/coreos-overlay/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/flatcar/coreos-overlay/tags',
# ...
#       'starred_url': 'https://api.github.com/users/rdkcentral/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rdkcentral/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rdkcentral/orgs',
#       'repos_url': 'https://api.github.com/users/rdkcentral/repos',
#       'events_url': 'https://api.github.com/users/rdkcentral/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rdkcentral/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 244331113,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQzMzExMTM=',
#       'name': 'Thunder',
#       'full_name': 'rdkcentral/Thunder',
#       'private': False,
#       'owner': {'login': 'rdkcentral',
#        'id': 35509157,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM1NTA5MTU3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/35509157?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rdkcentral',
#        'html_url': 'https://github.com/rdkcentral',
#        'followers_url': 'https://api.github.com/users/rdkcentral/followers',
#        'following_url': 'https://api.github.com/users/rdkcentral/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rdkcentral/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rdkcentral/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rdkcentral/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rdkcentral/orgs',
#        'repos_url': 'https://api.github.com/users/rdkcentral/repos',
#        'events_url': 'https://api.github.com/users/rdkcentral/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rdkcentral/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rdkcentral/Thunder',
#       'description': 'Thunder (aka WPEFramework)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rdkcentral/Thunder',
#       'forks_url': 'https://api.github.com/repos/rdkcentral/Thunder/forks',
#       'keys_url': 'https://api.github.com/repos/rdkcentral/Thunder/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rdkcentral/Thunder/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rdkcentral/Thunder/teams',
#       'hooks_url': 'https://api.github.com/repos/rdkcentral/Thunder/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rdkcentral/Thunder/events',
#       'assignees_url': 'https://api.github.com/repos/rdkcentral/Thunder/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rdkcentral/Thunder/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rdkcentral/Thunder/tags',
#       'blobs_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rdkcentral/Thunder/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rdkcentral/Thunder/languages',
#       'stargazers_url': 'https://api.github.com/repos/rdkcentral/Thunder/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rdkcentral/Thunder/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rdkcentral/Thunder/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rdkcentral/Thunder/subscription',
#       'commits_url': 'https://api.github.com/repos/rdkcentral/Thunder/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rdkcentral/Thunder/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rdkcentral/Thunder/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rdkcentral/Thunder/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rdkcentral/Thunder/merges',
#       'archive_url': 'https://api.github.com/repos/rdkcentral/Thunder/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rdkcentral/Thunder/downloads',
#       'issues_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rdkcentral/Thunder/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rdkcentral/Thunder/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rdkcentral/Thunder/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rdkcentral/Thunder/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rdkcentral/Thunder/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rdkcentral/Thunder/deployments',
#       'created_at': '2020-03-02T09:30:29Z',
#       'updated_at': '2023-01-31T17:57:08Z',
#       'pushed_at': '2023-02-05T17:11:50Z',
#       'git_url': 'git://github.com/rdkcentral/Thunder.git',
#       'ssh_url': 'git@github.com:rdkcentral/Thunder.git',
#       'clone_url': 'https://github.com/rdkcentral/Thunder.git',
#       'svn_url': 'https://github.com/rdkcentral/Thunder',
#       'homepage': None,
#       'size': 52138,
#       'stargazers_count': 19,
#       'watchers_count': 19,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 96,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 96,
#       'open_issues': 14,
#       'watchers': 19,
#       'default_branch': 'master'}},
#     'base': {'label': 'rdkcentral:master',
#      'ref': 'master',
#      'sha': 'e4b1b34c34b3b2bf8c9c641b4c33efd24e11d70c',
#      'user': {'login': 'rdkcentral',
#       'id': 35509157,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM1NTA5MTU3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/35509157?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rdkcentral',
#       'html_url': 'https://github.com/rdkcentral',
#       'followers_url': 'https://api.github.com/users/rdkcentral/followers',
#       'following_url': 'https://api.github.com/users/rdkcentral/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rdkcentral/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rdkcentral/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rdkcentral/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rdkcentral/orgs',
#       'repos_url': 'https://api.github.com/users/rdkcentral/repos',
#       'events_url': 'https://api.github.com/users/rdkcentral/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rdkcentral/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 244331113,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDQzMzExMTM=',
#       'name': 'Thunder',
#       'full_name': 'rdkcentral/Thunder',
#       'private': False,
#       'owner': {'login': 'rdkcentral',
#        'id': 35509157,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM1NTA5MTU3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/35509157?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rdkcentral',
#        'html_url': 'https://github.com/rdkcentral',
#        'followers_url': 'https://api.github.com/users/rdkcentral/followers',
#        'following_url': 'https://api.github.com/users/rdkcentral/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rdkcentral/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rdkcentral/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rdkcentral/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rdkcentral/orgs',
#        'repos_url': 'https://api.github.com/users/rdkcentral/repos',
#        'events_url': 'https://api.github.com/users/rdkcentral/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rdkcentral/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rdkcentral/Thunder',
#       'description': 'Thunder (aka WPEFramework)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rdkcentral/Thunder',
#       'forks_url': 'https://api.github.com/repos/rdkcentral/Thunder/forks',
#       'keys_url': 'https://api.github.com/repos/rdkcentral/Thunder/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rdkcentral/Thunder/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rdkcentral/Thunder/teams',
#       'hooks_url': 'https://api.github.com/repos/rdkcentral/Thunder/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rdkcentral/Thunder/events',
#       'assignees_url': 'https://api.github.com/repos/rdkcentral/Thunder/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rdkcentral/Thunder/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rdkcentral/Thunder/tags',
#       'blobs_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rdkcentral/Thunder/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rdkcentral/Thunder/languages',
#       'stargazers_url': 'https://api.github.com/repos/rdkcentral/Thunder/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rdkcentral/Thunder/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rdkcentral/Thunder/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rdkcentral/Thunder/subscription',
#       'commits_url': 'https://api.github.com/repos/rdkcentral/Thunder/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rdkcentral/Thunder/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rdkcentral/Thunder/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rdkcentral/Thunder/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rdkcentral/Thunder/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rdkcentral/Thunder/merges',
#       'archive_url': 'https://api.github.com/repos/rdkcentral/Thunder/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rdkcentral/Thunder/downloads',
#       'issues_url': 'https://api.github.com/repos/rdkcentral/Thunder/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rdkcentral/Thunder/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rdkcentral/Thunder/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rdkcentral/Thunder/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rdkcentral/Thunder/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rdkcentral/Thunder/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rdkcentral/Thunder/deployments',
#       'created_at': '2020-03-02T09:30:29Z',
#       'updated_at': '2023-01-31T17:57:08Z',
#       'pushed_at': '2023-02-05T17:11:50Z',
#       'git_url': 'git://github.com/rdkcentral/Thunder.git',
#       'ssh_url': 'git@github.com:rdkcentral/Thunder.git',
#       'clone_url': 'https://github.com/rdkcentral/Thunder.git',
#       'svn_url': 'https://github.com/rdkcentral/Thunder',
#       'homepage': None,
#       'size': 52138,
#       'stargazers_count': 19,
#       'watchers_count': 19,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 96,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 96,
#       'open_issues': 14,
#       'watchers': 19,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/pulls/1229'},
#      'html': {'href': 'https://github.com/rdkcentral/Thunder/pull/1229'},
#      'issue': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/issues/1229'},
#      'comments': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/issues/1229/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/pulls/1229/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/pulls/1229/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rdkcentral/Thunder/statuses/65ef1e0603eeb839882dbaf645d3ecbb2a973455'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z',
#   'org': {'id': 35509157,
#    'login': 'rdkcentral',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rdkcentral',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35509157?'}},
#  {'id': '26890895070',
#   'type': 'PushEvent',
#   'actor': {'id': 123444366,
#    'login': 'Sanjay-Suryavanshi',
#    'display_login': 'Sanjay-Suryavanshi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sanjay-Suryavanshi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123444366?'},
#   'repo': {'id': 596435168,
#    'name': 'Sanjay-Suryavanshi/Sanjay-Suryavanshi-dev.github.io',
#    'url': 'https://api.github.com/repos/Sanjay-Suryavanshi/Sanjay-Suryavanshi-dev.github.io'},
#   'payload': {'push_id': 12520958366,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a77e56674557409bc2e751860ee179ca55f4a4a0',
#    'before': 'a2fad908d95c4c8628fcc132a8ca6846e334c304',
#    'commits': [{'sha': 'a77e56674557409bc2e751860ee179ca55f4a4a0',
#      'author': {'email': '123444366+Sanjay-Suryavanshi@users.noreply.github.com',
#       'name': 'Sanjay Suryavanshi'},
#      'message': 'Delete CNAME',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sanjay-Suryavanshi/Sanjay-Suryavanshi-dev.github.io/commits/a77e56674557409bc2e751860ee179ca55f4a4a0'}]},
#   'public': True,
#   'created_at': '2023-02-06T08:50:56Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-63e0c0e8-25975f195b07dbff64c5b82a'},
#  'origin': '140.116.177.9',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-63e0c106-29f83ff3789dbfdd51a265f0'},
#  'json': None,
#  'origin': '140.116.177.9',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-63e0c10d-4e615e8545ba00664c5c2e64'},
#  'json': None,
#  'origin': '140.116.177.9',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
